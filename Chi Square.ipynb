# %%
# !pip install numpy pandas matplotlib opencv-python scikit-image
# Out:
# Requirement already satisfied: numpy in c:\users\kedar\appdata\local\programs\python\python39\lib\site-packages (1.22.2)
# Requirement already satisfied: pandas in c:\users\kedar\appdata\local\programs\python\python39\lib\site-packages (1.4.1)
# Requirement already satisfied: matplotlib in c:\users\kedar\appdata\local\programs\python\python39\lib\site-packages (3.5.1)
# Requirement already satisfied: opencv-python in c:\users\kedar\appdata\local\programs\python\python39\lib\site-packages (4.5.5.62)
# Requirement already satisfied: scikit-image in c:\users\kedar\appdata\local\programs\python\python39\lib\site-packages (0.19.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\kedar\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kedar\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\kedar\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\kedar\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\kedar\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\kedar\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (3.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\kedar\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kedar\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (4.29.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\kedar\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (9.1.0)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\kedar\appdata\local\programs\python\python39\lib\site-packages (from scikit-image) (2022.2.9)
# Requirement already satisfied: networkx>=2.2 in c:\users\kedar\appdata\local\programs\python\python39\lib\site-packages (from scikit-image) (2.6.3)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\kedar\appdata\local\programs\python\python39\lib\site-packages (from scikit-image) (1.2.0)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\kedar\appdata\local\programs\python\python39\lib\site-packages (from scikit-image) (1.8.0)
# Requirement already satisfied: imageio>=2.4.1 in c:\users\kedar\appdata\local\programs\python\python39\lib\site-packages (from scikit-image) (2.16.1)
# WARNING: You are using pip version 21.1.3; however, version 22.0.4 is available.
# You should consider upgrading via the 'c:\users\kedar\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
import time
import random
import cv2
import os
import math
import numpy as np
import matplotlib.pyplot as plt

from matplotlib.widgets import Cursor
from PIL import Image
import hashlib
from yolo_opencv import detect_object
import pandas as pd

# %matplotlib inline

#confuse and diffuse scheme
#date : 2019.6.3 10.56

# def PL_PWLCM(y0,p2,exp32):
#     y1=0
#     if y0<p2:
#         y1 = math.floor(exp32*y0/p2)
#     elif p2<y0 and y0 < exp32/2:
#         y1 = math.floor(exp32*(y0-p2)/(exp32/2 - p2))
#     elif y0 == exp32/2 :
#         y1 = 0
#     else:
#         y1 = PL_PWLCM(exp32-y0, p2, exp32)
#     return y1


def SkewTent(y0,p2,exp32):
    y1=0
    if y0<p2:
        y1 = math.floor(exp32*y0/p2)
    elif y0 == p2 :
        y1 = exp32-1
    elif p2<y0 and y0 < exp32:
        y1 = math.floor(exp32*(exp32-y0)/(exp32 - p2))
    return y1

'''
PWLCM MAP
'''
def SCCS_MAP(y0, p2, exp32):
    y1=0
    if y0<p2:
        y1 = math.floor(exp32*y0/p2)
    elif p2<y0 and y0 < exp32/2:
        y1 = math.floor(exp32*(y0-p2)/(exp32/2 - p2))
    elif y0 == exp32/2 :
        y1 = 0
    else:
        y1 = SCCS_MAP(exp32-y0, p2, exp32)
    return y1

'''
Logistic Map used in CML Map
'''
def PL_Logistic(x0,exp32):
    x1 = math.floor(4*x0*(exp32-x0)/exp32)
    return x1

'''
CML MAP
'''
def CCCS_MAP(x0,exp32, ep=0.5):
    x0 = x0 % 256
    log_x1 = PL_Logistic(x0, exp32)
    x1 = (1-ep) * log_x1 + (ep/2) * log_x1 + log_x1
    return math.floor(x1)

def PL_PWLCM_Logistic(x0,y0,p1,z0,p2):
    exp32 = 4294967296
    y1 = SCCS_MAP(y0,p1,exp32)
    x1 = SkewTent(z0,p2,exp32)
    z1 = CCCS_MAP(x0,exp32)
    temp1 = x1 ^ y1
    r1 = (temp1 + z1) % exp32
    return x1,y1,z1,r1

def PWLCM_Init(x0,y0,p1,p2,exp32,n):
    x1 = x0
    y1 = y0
    for i in range(n):
        x1 = SCCS_MAP(x1,p1,exp32)
        y1 = SCCS_MAP(y1,p2,exp32)
    return x1,y1

def Logistic_Init(x0,n,exp32):
    x1 = x0
    for i in range(n):
        x1 = CCCS_MAP(x1,exp32)
    return x1

def InitPRNG(x0,y0,p1,z0,p2,n):
    exp32 = 4294967296
    for i in range(n):
        y1,z1 = PWLCM_Init(y0,z0,p1,p2,exp32,n)
        x1 = SCCS_MAP(x0,n,exp32)
    return x1,y1,z1

# get the second column
def takeSecond(elem):
    return elem[1]
#key generation v2 output : PRNGlist, 32-Bit sorted sorting index 
def getPRNG(a,b,c,x0,y0,p1,z0,p2):
    iLen = math.ceil(a*b*c)
    SortLen = (a)*(b)*c # if the a and c are not the interal multiple of 2, discard the last row and column 
    #print('the prng interation rounds is :',iLen)
    #print("the sort list's len is :", SortLen)
    SortList = list();
    ValueList = np.zeros(a*b*c, dtype = int, order = 'C')
    time_start=time.time()
    for iNum in range(iLen):
        #print('total:', iLen, '+++++++Now:',iNum)
        x0,y0,z0,res = PL_PWLCM_Logistic(x0,y0,p1,z0,p2)
        if iNum < SortLen:
            SortList.append([iNum,res])
        if (iNum+1)*4 <= a*b*c:
            ValueList[iNum*4] = (res >> 24) & 0xff
            ValueList[iNum*4+1] = (res >> 16) & 0x00ff
            ValueList[iNum*4+2] = (res >> 8) & 0x0000ff
            ValueList[iNum*4+3] = (res >> 0) & 0x000000ff
        else:
            tail = a * b * c % 4
            shiftUnit = [0xff,0x00ff,0x0000ff,0x000000ff]
            for i in range(tail):
                if iNum * 4 + i < len(ValueList):
                    ValueList[iNum*4+i] = (res >> 24-i*8) & shiftUnit[i]
    time_end=time.time()
    #print('PRNG Generation time cost:',time_end-time_start,'s')
#     print(SortList)
    SortList.sort(key=takeSecond)
#     print(SortList)
    if c == 1: #gray
        return SortList,ValueList.reshape(a,b),x0,y0,z0
    else:
        return SortList,ValueList.reshape(a,b,c),x0,y0,z0

# Initialization
# def getParas(key):
#     p2 = key & 0x7fffffff
#     z0 = (key>>31) & 0x7fffffff
#     p1 = (key>>62) & 0x7fffffff
#     y0 = (key>>93) & 0x7fffffff
#     x0 = (key>>124) & 0xffffffff
    
#     x0,y0,z0 = InitPRNG(x0,y0,p1,z0,p2,20)    
#     return x0,y0,p1,z0,p2

def generate_key(key):
    k1 = hashlib.sha512(key)
    k1 = bin(int.from_bytes(k1.digest(), "big"))[2:494]
    k2 = hashlib.sha512(k1.encode("utf-8"))
    k2 = bin(int.from_bytes(k2.digest(), "big"))[2:494]
    return k2

def getKeys(key):
    k1 = key[:80]
    k2 = key[160:160+80]
    k3 = key[240:240+36]
    k4 = key[276: 276+36]
    k5 = key[312:348]
    k6 = key[348:384]
    k7 = key[384:420]
    k8 = key[420:456]
    k9 = key[456:492]
    k11 = bin(int(k1[:40], 2) ^ int(k2[:40], 2))
    k12 = bin(int(k1[40:], 2) ^ int(k2[40:], 2))
    k13 = bin(int(k3, 2) ^ int(k4, 2))
    k14 = bin(int(k5, 2) ^ int(k6, 2))
    k15 = bin(int(k7, 2) ^ int(k8, 2) ^ int(k9, 2))
    
#     x1 = int(k11, 2) / 2**40
#     x2 = int(k12, 2) / 2**40
#     x3 = int(k13, 2) / 2**35
#     x4 = int(k14, 2) / 2**35
    x5 = int(k15, 2) / 2**35
    x6 = 0.87 + ((int(k13, 2) ^ int(k14, 2)) / 2**35) % 0.13
    x7 = (int(k13, 2) ^ int(k15, 2)) / 2**35
    x8 = 0.87 + ((int(k14, 2) ^ int(k15, 2)) / 2**35) % 0.13
    x9 = (int(k13, 2) ^ int(k14, 2) ^ int(k15, 2)) / 2**35
    
#     x1 = x1 ^ x9
#     x2 = x2 ^ x8
#     x3 = x3 ^ x7
#     x4 = x4 ^ x6
#     x5 = x5 ^ (x6 ^ x7 ^ x8 ^ x9)
       
    
    return list(map(lambda x: x % 1, [x5, x6, x7, x8, x9]))

def getParas(key):
    key = generate_key(key)
    xs = getKeys(key)
    val = 2 ** 32
    x0 = xs[0] * val
    y0 = xs[1] * val
    z0 = xs[2] * val
    p1 = xs[3] * val
    p2 = xs[4] * val
    
    x0,y0,z0 = InitPRNG(x0,y0,p1,z0,p2,20)    
    return x0,y0,p1,z0,p2

def Enc(a,SortKey,ValueKey,scale,diffRound=1):
#     print(SortKey, SortKey.shape)
    w,h = a.shape
    k = SortKey
    #confusion
    c =  np.zeros((w,h), dtype=int)
    c = a.copy().flatten()
#     print(len(k))
    for i in range(len(k)):
        temp = c[i]
        c[i] = c[k[i]]
        c[k[i]] = temp
        
    b = np.zeros((w,h), dtype=int)
    b = c.copy().reshape((w,h))
    for iwhole in range(diffRound):
        #step2.1 diffuse row
        for iRow in range(0,w,1):
#             print(iRow, end="")
            if iRow == 0:
                b[iRow,:] = (b[-1,:] + b[iRow,:] + ValueKey[iRow,:]) % scale
            else:
                b[iRow,:] = (b[iRow-1,:] + b[iRow,:] + ValueKey[iRow,:]) % scale

        #step2.2 diffuse column
        for iCol in range(0,h,1):
            if iCol == 0:
                b[:, iCol] = (b[:, -1] + b[:, iCol] + ValueKey[:, iCol]) % scale
            else:
                b[:, iCol] = (b[:, iCol-1] + b[:, iCol] + ValueKey[:, iCol]) % scale


    return b

def Dec(a,SortKey,ValueKey,scale,diffRound=1):
    w,h = a.shape
    c =  np.zeros((w,h), dtype=int)
    c = a.copy()
    k = SortKey
    
    for iwhole in range(diffRound):
        for iCol in range(h-1,-1,-1):
            if iCol == 0:
                c[:, iCol] = (c[:, iCol] - c[:, -1] - ValueKey[:, iCol]) % scale
            else:
                c[:, iCol] = (c[:, iCol] - c[:, iCol-1] - ValueKey[:, iCol]) % scale
        for iRow in range(w-1,-1,-1):
            if iRow == 0:
                c[iRow,:] = (c[iRow,:] - c[-1,:] - ValueKey[iRow,:])% scale
            else:
                c[iRow,:] = (c[iRow,:] - c[iRow-1,:] - ValueKey[iRow,:])% scale 
    
    b =  np.zeros((w,h), dtype=int)
    b = c.copy().flatten()
    #confusion
    for i in range(len(k)-1, -1, -1):
        temp = b[i]
        b[i] = b[k[i]]
        b[k[i]] = temp
    return b.reshape((w,h))


def DoEnc(img,k=None, round=2):
    n = round # Encryption round
    w,h = img.shape #return row and column
    keys = []
    for i in range(n):
        x0,y0,p1,z0,p2 = getParas(img)
        keys.append((x0, y0, p1, z0, p2))
#         print("Encryption: ", (x0, y0, p1, z0, p2))
        sort,valuekey,x0,y0,z0 = getPRNG(w,h,1,x0,y0,p1,z0,p2)
        arr = np.array(sort)
        sortkey = arr[:,0]
        img = Enc(img,sortkey,valuekey,256,2)
    return img, keys


def DoDec(img,k,round = 2):
    n = round # Encryption round    
    w,h = img.shape #return row and column
    for i in range(n-1,-1,-1):
        x0,y0,p1,z0,p2 = k[i]
#         print("Decryption: ", (x0, y0, p1, z0, p2))
        sort,valuekey,x0,y0,z0 = getPRNG(w,h,1,x0,y0,p1,z0,p2)
        arr = np.array(sort)
        sortkey = arr[:,0]
        img = Dec(img,sortkey,valuekey,256,2)
    return img

# %%
def DoColorEnc(img,k=None, round=2):
    n = round # Encryption round
    #step1. initialization
    
    w,h,d = img.shape #return row and column
    img = img.reshape((w,h*d))
#     print(img.shape)
    keys = list()
    for i in range(n):
        x0,y0,p1,z0,p2 = getParas(np.ascontiguousarray(img))
        if k is not None:
            z0 += 1
        keys.append((x0,y0,p1,z0,p2))
        sort,valuekey,x0,y0,z0 = getPRNG(w,h*d,1,x0,y0,p1,z0,p2)
        arr = np.array(sort)
        sortkey = arr[:,0]
        img = Enc(img,sortkey,valuekey,256,2)
    
    img = img.reshape((w,h,d))
    return img, keys

def DoColorDec(img, k, round=2):
    n = round # Encryption round    
    w,h,d = img.shape #return row and column
    img = img.reshape((w,h*d))
    for i in range(n-1,-1,-1):
        x0,y0,p1,z0,p2 = k[i]
        sort,valuekey,x0,y0,z0 = getPRNG(w,h*d,1,x0,y0,p1,z0,p2)
        arr = np.array(sort)
        sortkey = arr[:,0]
        img = Dec(img,sortkey,valuekey,256,2)
    img = img.reshape((w,h,d))
    return img

def ObjectDetectionTest(file, crop=True, draw=False):
    og = cv2.imread(file)
    og = cv2.cvtColor(og, cv2.COLOR_BGR2RGB)
    
    if crop:
        start_det = time.perf_counter()
        img, (x, y) = detect_object(file,draw=draw)
        end_det = time.perf_counter()
        print("Detection Time:", (end_det - start_det))
        if img.size > 0:
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        else:
            print(img)
            print("No Object Detected!")
            return
    else:
        img = og

#     img = cv2.imread(file)
    print("Image Size:", og.shape)
    print("Detected Shape", img.shape)

    plt.figure(figsize=(20, 18))
    plt.subplot(1, 3, 1)
    plt.imshow(og, cmap="gray")
    plt.title("Original Image")
    
    if crop:
        plt.subplot(1, 3, 2)
        plt.imshow(img, cmap="gray")
        plt.title("Object Detected")
    
    start_enc = time.perf_counter()
    encrypted, keys = DoColorEnc(img, round=1)
    end_enc = time.perf_counter()
    print("Encryption Time:", (end_enc - start_enc))
    
    start_dec = time.perf_counter()
    decrypted = DoColorDec(img, keys, round=1)
    end_dec = time.perf_counter()
    print("Decryption Time:", (end_dec - start_dec))
    
    if crop:
        og[y:y+encrypted.shape[0], x: x+encrypted.shape[1]] = encrypted
    else:
        og = encrypted
    
    plt.subplot(1, 3, 3)
    plt.imshow(og)
    plt.title("Encrypted")
    plt.show()
    
    if crop:
         return (file, og.shape, (end_enc - start_enc), (end_dec - start_enc), (x, y, img.shape[0], img.shape[1]))
    
    return (file, og.shape, (end_enc - start_enc), (end_dec - start_enc))
    
# ObjectDetectionTest("./new/group.jpg")
# ObjectDetectionTest("./new/group.jpg", crop=False)

def ColorDetectionTest(draw=False, to_file=None):
    path = "./new/"
    arr = []
    for file in os.listdir(path):
        print(path+file)
        _, shape, enctime, dectime, coords = ObjectDetectionTest(path + file, draw=draw)
        _, shape, totalenctime, totaldectime = ObjectDetectionTest(path + file, crop=False)
        arr.append((file, shape, totalenctime, totaldectime, enctime, dectime, coords[0], coords[1], coords[2], coords[3]))
    arr = np.array(arr)
    arr = pd.DataFrame(arr, columns=["File Name", "Image Size", "Total Encryption Time", "Total Decryption Time", "Encryption Time", "Decryption Time", "X", "Y", "Width", "Height"])
    
    print(arr.head())
    if to_file:
        arr.to_csv(to_file, index=False)

# ColorDetectionTest(draw=True, to_file= "data.csv")

# %%
# Chi-square analysis
def getFre(value,img):
    a,b = img.shape
    icount = 0.0
    for i in range(a):
        for j in range(b):
            if img[i][j] == value:
                icount += 1
    return icount
def ChiSquare(img):
    a,b = img.shape
#     print("image's shape", img.shape)
    e = a*b/256
    res = 0
    for i in range(256):
        oi = getFre(i,img)
        temp = math.pow(oi-e,2) / e
        res += temp
#     print("Chi-square value:", res)
    return res

def calcChiSquareList():
    path = "./new/"
    pictures = os.listdir(path)
#     key = [0x7833A013F4DB0018F4FB4031E9F680BC614A,0x7833A013F4DB0018F4FB4032E9F680BC614B] 
    icount = 0
    for picName in pictures:
        picPath = path + picName
        print(picName)
        lenna_img = np.array(Image.open(picPath))
        lenna_cipher, keys = DoColorEnc(lenna_img,round=1)
        resR = ChiSquare(lenna_cipher[:,:,0])
        resG = ChiSquare(lenna_cipher[:,:,1])
        resB = ChiSquare(lenna_cipher[:,:,2])
        
        print("R Chi-Square Value:", resR)
        print("G Chi-Square Value:", resG)
        print("B Chi-Square Value:", resB)
        print("Average Chi-Square Value:", (resR + resG + resB)/3)
    return 0
        
calcChiSquareList()
# Out:
# 121.png
# R Chi-Square Value: 242.8710940993399
# G Chi-Square Value: 244.89152014881336
# B Chi-Square Value: 237.33295176089706
# Average Chi-Square Value: 241.6985220030168
# 181.png
# R Chi-Square Value: 264.21875
# G Chi-Square Value: 227.875
# B Chi-Square Value: 265.0
# Average Chi-Square Value: 252.36458333333334
# 184.png
# R Chi-Square Value: 266.1796875
# G Chi-Square Value: 260.9140625
# B Chi-Square Value: 243.3203125
# Average Chi-Square Value: 256.8046875
# 204.png
# R Chi-Square Value: 218.03125
# G Chi-Square Value: 254.328125
# B Chi-Square Value: 218.859375
# Average Chi-Square Value: 230.40625
# 207.png
# R Chi-Square Value: 260.7890625
# G Chi-Square Value: 244.953125
# B Chi-Square Value: 250.2734375
# Average Chi-Square Value: 252.00520833333334
# 209.png
# R Chi-Square Value: 261.6953125
# G Chi-Square Value: 238.484375
# B Chi-Square Value: 247.234375
# Average Chi-Square Value: 249.13802083333334
# 21.png
# R Chi-Square Value: 273.71510619650553
# G Chi-Square Value: 259.81285546459804
# B Chi-Square Value: 267.6942584891936
# Average Chi-Square Value: 267.07407338343234
# 222.png
# R Chi-Square Value: 276.90625
# G Chi-Square Value: 221.3671875
# B Chi-Square Value: 265.5
# Average Chi-Square Value: 254.59114583333334
# 272.png
# R Chi-Square Value: 308.0390625
# G Chi-Square Value: 262.03125
# B Chi-Square Value: 312.21875
# Average Chi-Square Value: 294.0963541666667
# 312.png
# R Chi-Square Value: 252.875
# G Chi-Square Value: 281.484375
# B Chi-Square Value: 260.265625
# Average Chi-Square Value: 264.875
# 335.png
# R Chi-Square Value: 234.59375
# G Chi-Square Value: 253.421875
# B Chi-Square Value: 230.34375
# Average Chi-Square Value: 239.453125
# 362.png
# R Chi-Square Value: 271.7421875
# G Chi-Square Value: 285.390625
# B Chi-Square Value: 286.2578125
# Average Chi-Square Value: 281.1302083333333
# 373.png
# R Chi-Square Value: 248.8828125
# G Chi-Square Value: 245.265625
# B Chi-Square Value: 210.6875
# Average Chi-Square Value: 234.9453125
# 398.png
# R Chi-Square Value: 257.953125
# G Chi-Square Value: 280.9296875
# B Chi-Square Value: 287.2109375
# Average Chi-Square Value: 275.3645833333333
# 406.png
# R Chi-Square Value: 236.84375
# G Chi-Square Value: 235.4765625
# B Chi-Square Value: 254.265625
# Average Chi-Square Value: 242.1953125
# 520.png
# R Chi-Square Value: 224.50112450448978
# G Chi-Square Value: 228.8875657309277
# B Chi-Square Value: 241.98061645497918
# Average Chi-Square Value: 231.7897688967989
# 526.png
# R Chi-Square Value: 238.76105997210573
# G Chi-Square Value: 240.27313807531354
# B Chi-Square Value: 257.66114365411437
# Average Chi-Square Value: 245.5651139005112
# 58.png
# R Chi-Square Value: 301.0794448624159
# G Chi-Square Value: 282.68806326135325
# B Chi-Square Value: 276.86904323606143
# Average Chi-Square Value: 286.87885045327687
# 80.png
# R Chi-Square Value: 249.6941244032878
# G Chi-Square Value: 237.22077455942014
# B Chi-Square Value: 283.9969850328415
# Average Chi-Square Value: 256.9706279985165
# group.jpg
# R Chi-Square Value: 278.04411764705907
# G Chi-Square Value: 255.96470588235292
# B Chi-Square Value: 244.07941176470595
# Average Chi-Square Value: 259.3627450980393
# 0

# %% [markdown]
# # Cropped Chi Square

# %%
# Chi-square analysis
def getFre(value,img):
    a,b = img.shape
    icount = 0.0
    for i in range(a):
        for j in range(b):
            if img[i][j] == value:
                icount += 1
    return icount
def ChiSquare(img):
    a,b = img.shape
#     print("image's shape", img.shape)
    e = a*b/256
    res = 0
    for i in range(256):
        oi = getFre(i,img)
        temp = math.pow(oi-e,2) / e
        res += temp
#     print("Chi-square value:", res)
    return res

def cropped_calcChiSquareList():
    path = "./new/"
    pictures = os.listdir(path)
#     key = [0x7833A013F4DB0018F4FB4031E9F680BC614A,0x7833A013F4DB0018F4FB4032E9F680BC614B] 
    icount = 0
    for picName in pictures:
        picPath = path + picName
        print(picName)
#         lenna_img = np.array(Image.open(picPath))
        lenna_img, (x, y) = detect_object()
        lenna_cipher, keys = DoColorEnc(lenna_img,round=1)
        resR = ChiSquare(lenna_cipher[:,:,0])
        resG = ChiSquare(lenna_cipher[:,:,1])
        resB = ChiSquare(lenna_cipher[:,:,2])
        
        print("R Chi-Square Value:", resR)
        print("G Chi-Square Value:", resG)
        print("B Chi-Square Value:", resB)
        print("Average Chi-Square Value:", (resR + resG + resB)/3)
    return 0
        
cropped_calcChiSquareList()
# Out:
# 121.png
# R Chi-Square Value: 243.0619373033954
# G Chi-Square Value: 315.1403261380482
# B Chi-Square Value: 210.9011100263949
# Average Chi-Square Value: 256.3677911559462
# 181.png
# R Chi-Square Value: 277.02681318681306
# G Chi-Square Value: 241.41186813186806
# B Chi-Square Value: 255.309010989011
# Average Chi-Square Value: 257.91589743589736
# 184.png
# R Chi-Square Value: 235.31078904991958
# G Chi-Square Value: 255.11884057971034
# B Chi-Square Value: 248.41996779388097
# Average Chi-Square Value: 246.2831991411703
# 204.png
# R Chi-Square Value: 268.14313830738956
# G Chi-Square Value: 252.2719627840399
# B Chi-Square Value: 259.4861334764716
# Average Chi-Square Value: 259.96707818930037
# 207.png
# R Chi-Square Value: 253.05801562869985
# G Chi-Square Value: 261.6661141368694
# B Chi-Square Value: 223.59649538242945
# Average Chi-Square Value: 246.1068750493329
# 209.png
# R Chi-Square Value: 264.0551648217236
# G Chi-Square Value: 274.62332579047177
# B Chi-Square Value: 242.27692495871835
# Average Chi-Square Value: 260.31847185697126
# 21.png
# R Chi-Square Value: 242.1775453983249
# G Chi-Square Value: 268.98363973688674
# B Chi-Square Value: 252.79923539663804
# Average Chi-Square Value: 254.65347351061655
# 222.png
# R Chi-Square Value: 220.12121212121224
# G Chi-Square Value: 223.85081585081582
# B Chi-Square Value: 245.63170163170156
# Average Chi-Square Value: 229.86790986790984
# 272.png
# R Chi-Square Value: 252.69841269841277
# G Chi-Square Value: 255.05339105339135
# B Chi-Square Value: 264.24242424242425
# Average Chi-Square Value: 257.3314093314095
# 312.png
# R Chi-Square Value: 244.70856102003643
# G Chi-Square Value: 213.37304189435318
# B Chi-Square Value: 248.87419550698246
# Average Chi-Square Value: 235.651932807124
# 335.png
# R Chi-Square Value: 287.79172749391756
# G Chi-Square Value: 251.021573398216
# B Chi-Square Value: 258.8905109489055
# Average Chi-Square Value: 265.90127061367974
# 362.png
# R Chi-Square Value: 278.4853354760946
# G Chi-Square Value: 264.7030936118921
# B Chi-Square Value: 262.4403374849334
# Average Chi-Square Value: 268.54292219097334
# 373.png
# R Chi-Square Value: 249.43263263263256
# G Chi-Square Value: 274.9813813813814
# B Chi-Square Value: 255.3009009009009
# Average Chi-Square Value: 259.90497163830497
# 398.png
# R Chi-Square Value: 240.1481481481482
# G Chi-Square Value: 309.1111111111111
# B Chi-Square Value: 248.44444444444446
# Average Chi-Square Value: 265.90123456790127
# 406.png
# R Chi-Square Value: 241.3199454793276
# G Chi-Square Value: 251.7646524307134
# B Chi-Square Value: 251.81117673784655
# Average Chi-Square Value: 248.29859154929582
# 520.png
# R Chi-Square Value: 270.22113022113024
# G Chi-Square Value: 241.67185367185374
# B Chi-Square Value: 239.78487578487596
# Average Chi-Square Value: 250.55928655928665
# 526.png
# R Chi-Square Value: 242.23043884220377
# G Chi-Square Value: 285.96078431372564
# B Chi-Square Value: 233.82857142857145
# Average Chi-Square Value: 254.0065981948336
# 58.png
# R Chi-Square Value: 286.5128205128206
# G Chi-Square Value: 248.71794871794845
# B Chi-Square Value: 228.6153846153845
# Average Chi-Square Value: 254.61538461538453
# 80.png
# R Chi-Square Value: 297.1304347826089
# G Chi-Square Value: 231.43478260869546
# B Chi-Square Value: 258.65217391304355
# Average Chi-Square Value: 262.4057971014493
# group.jpg
# R Chi-Square Value: 269.4850436524974
# G Chi-Square Value: 290.417174753113
# B Chi-Square Value: 243.83374838986694
# Average Chi-Square Value: 267.91198893182576
# 0
