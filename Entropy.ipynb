# %%
# !pip install numpy pandas matplotlib opencv-python scikit-image
# Out:
# Requirement already satisfied: numpy in c:\users\kedar\appdata\local\programs\python\python39\lib\site-packages (1.22.2)
# Requirement already satisfied: pandas in c:\users\kedar\appdata\local\programs\python\python39\lib\site-packages (1.4.1)
# Requirement already satisfied: matplotlib in c:\users\kedar\appdata\local\programs\python\python39\lib\site-packages (3.5.1)
# Requirement already satisfied: opencv-python in c:\users\kedar\appdata\local\programs\python\python39\lib\site-packages (4.5.5.62)
# Requirement already satisfied: scikit-image in c:\users\kedar\appdata\local\programs\python\python39\lib\site-packages (0.19.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kedar\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\kedar\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\kedar\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kedar\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (4.29.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\kedar\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (3.0.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\kedar\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\kedar\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (9.1.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\kedar\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\kedar\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: imageio>=2.4.1 in c:\users\kedar\appdata\local\programs\python\python39\lib\site-packages (from scikit-image) (2.16.1)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\kedar\appdata\local\programs\python\python39\lib\site-packages (from scikit-image) (2022.2.9)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\kedar\appdata\local\programs\python\python39\lib\site-packages (from scikit-image) (1.8.0)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\kedar\appdata\local\programs\python\python39\lib\site-packages (from scikit-image) (1.2.0)
# Requirement already satisfied: networkx>=2.2 in c:\users\kedar\appdata\local\programs\python\python39\lib\site-packages (from scikit-image) (2.6.3)
# WARNING: You are using pip version 21.1.3; however, version 22.0.4 is available.
# You should consider upgrading via the 'c:\users\kedar\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
import time
import random
import cv2
import os
import math
import numpy as np
import matplotlib.pyplot as plt

from matplotlib.widgets import Cursor
from PIL import Image
import hashlib
from yolo_opencv import detect_object
import pandas as pd

# %matplotlib inline

#confuse and diffuse scheme
#date : 2019.6.3 10.56

# def PL_PWLCM(y0,p2,exp32):
#     y1=0
#     if y0<p2:
#         y1 = math.floor(exp32*y0/p2)
#     elif p2<y0 and y0 < exp32/2:
#         y1 = math.floor(exp32*(y0-p2)/(exp32/2 - p2))
#     elif y0 == exp32/2 :
#         y1 = 0
#     else:
#         y1 = PL_PWLCM(exp32-y0, p2, exp32)
#     return y1


def SkewTent(y0,p2,exp32):
    y1=0
    if y0<p2:
        y1 = math.floor(exp32*y0/p2)
    elif y0 == p2 :
        y1 = exp32-1
    elif p2<y0 and y0 < exp32:
        y1 = math.floor(exp32*(exp32-y0)/(exp32 - p2))
    return y1

'''
PWLCM MAP
'''
def SCCS_MAP(y0, p2, exp32):
    y1=0
    if y0<p2:
        y1 = math.floor(exp32*y0/p2)
    elif p2<y0 and y0 < exp32/2:
        y1 = math.floor(exp32*(y0-p2)/(exp32/2 - p2))
    elif y0 == exp32/2 :
        y1 = 0
    else:
        y1 = SCCS_MAP(exp32-y0, p2, exp32)
    return y1

'''
Logistic Map used in CML Map
'''
def PL_Logistic(x0,exp32):
    x1 = math.floor(4*x0*(exp32-x0)/exp32)
    return x1

'''
CML MAP
'''
def CCCS_MAP(x0,exp32, ep=0.5):
    x0 = x0 % 256
    log_x1 = PL_Logistic(x0, exp32)
    x1 = (1-ep) * log_x1 + (ep/2) * log_x1 + log_x1
    return math.floor(x1)

def PL_PWLCM_Logistic(x0,y0,p1,z0,p2):
    exp32 = 4294967296
    y1 = SCCS_MAP(y0,p1,exp32)
    x1 = SkewTent(z0,p2,exp32)
    z1 = CCCS_MAP(x0,exp32)
    temp1 = x1 ^ y1
    r1 = (temp1 + z1) % exp32
    return x1,y1,z1,r1

def PWLCM_Init(x0,y0,p1,p2,exp32,n):
    x1 = x0
    y1 = y0
    for i in range(n):
        x1 = SCCS_MAP(x1,p1,exp32)
        y1 = SCCS_MAP(y1,p2,exp32)
    return x1,y1

def Logistic_Init(x0,n,exp32):
    x1 = x0
    for i in range(n):
        x1 = CCCS_MAP(x1,exp32)
    return x1

def InitPRNG(x0,y0,p1,z0,p2,n):
    exp32 = 4294967296
    for i in range(n):
        y1,z1 = PWLCM_Init(y0,z0,p1,p2,exp32,n)
        x1 = SCCS_MAP(x0,n,exp32)
    return x1,y1,z1

# get the second column
def takeSecond(elem):
    return elem[1]
#key generation v2 output : PRNGlist, 32-Bit sorted sorting index 
def getPRNG(a,b,c,x0,y0,p1,z0,p2):
    iLen = math.ceil(a*b*c)
    SortLen = (a)*(b)*c # if the a and c are not the interal multiple of 2, discard the last row and column 
    #print('the prng interation rounds is :',iLen)
    #print("the sort list's len is :", SortLen)
    SortList = list();
    ValueList = np.zeros(a*b*c, dtype = int, order = 'C')
    time_start=time.time()
    for iNum in range(iLen):
        #print('total:', iLen, '+++++++Now:',iNum)
        x0,y0,z0,res = PL_PWLCM_Logistic(x0,y0,p1,z0,p2)
        if iNum < SortLen:
            SortList.append([iNum,res])
        if (iNum+1)*4 <= a*b*c:
            ValueList[iNum*4] = (res >> 24) & 0xff
            ValueList[iNum*4+1] = (res >> 16) & 0x00ff
            ValueList[iNum*4+2] = (res >> 8) & 0x0000ff
            ValueList[iNum*4+3] = (res >> 0) & 0x000000ff
        else:
            tail = a * b * c % 4
            shiftUnit = [0xff,0x00ff,0x0000ff,0x000000ff]
            for i in range(tail):
                if iNum * 4 + i < len(ValueList):
                    ValueList[iNum*4+i] = (res >> 24-i*8) & shiftUnit[i]
    time_end=time.time()
    #print('PRNG Generation time cost:',time_end-time_start,'s')
#     print(SortList)
    SortList.sort(key=takeSecond)
#     print(SortList)
    if c == 1: #gray
        return SortList,ValueList.reshape(a,b),x0,y0,z0
    else:
        return SortList,ValueList.reshape(a,b,c),x0,y0,z0

# Initialization
# def getParas(key):
#     p2 = key & 0x7fffffff
#     z0 = (key>>31) & 0x7fffffff
#     p1 = (key>>62) & 0x7fffffff
#     y0 = (key>>93) & 0x7fffffff
#     x0 = (key>>124) & 0xffffffff
    
#     x0,y0,z0 = InitPRNG(x0,y0,p1,z0,p2,20)    
#     return x0,y0,p1,z0,p2

def generate_key(key):
    k1 = hashlib.sha512(key)
    k1 = bin(int.from_bytes(k1.digest(), "big"))[2:494]
    k2 = hashlib.sha512(k1.encode("utf-8"))
    k2 = bin(int.from_bytes(k2.digest(), "big"))[2:494]
    return k2

def getKeys(key):
    k1 = key[:80]
    k2 = key[160:160+80]
    k3 = key[240:240+36]
    k4 = key[276: 276+36]
    k5 = key[312:348]
    k6 = key[348:384]
    k7 = key[384:420]
    k8 = key[420:456]
    k9 = key[456:492]
    k11 = bin(int(k1[:40], 2) ^ int(k2[:40], 2))
    k12 = bin(int(k1[40:], 2) ^ int(k2[40:], 2))
    k13 = bin(int(k3, 2) ^ int(k4, 2))
    k14 = bin(int(k5, 2) ^ int(k6, 2))
    k15 = bin(int(k7, 2) ^ int(k8, 2) ^ int(k9, 2))
    
#     x1 = int(k11, 2) / 2**40
#     x2 = int(k12, 2) / 2**40
#     x3 = int(k13, 2) / 2**35
#     x4 = int(k14, 2) / 2**35
    x5 = int(k15, 2) / 2**35
    x6 = 0.87 + ((int(k13, 2) ^ int(k14, 2)) / 2**35) % 0.13
    x7 = (int(k13, 2) ^ int(k15, 2)) / 2**35
    x8 = 0.87 + ((int(k14, 2) ^ int(k15, 2)) / 2**35) % 0.13
    x9 = (int(k13, 2) ^ int(k14, 2) ^ int(k15, 2)) / 2**35
    
#     x1 = x1 ^ x9
#     x2 = x2 ^ x8
#     x3 = x3 ^ x7
#     x4 = x4 ^ x6
#     x5 = x5 ^ (x6 ^ x7 ^ x8 ^ x9)
       
    
    return list(map(lambda x: x % 1, [x5, x6, x7, x8, x9]))

def getParas(key):
    key = generate_key(key)
    xs = getKeys(key)
    val = 2 ** 32
    x0 = xs[0] * val
    y0 = xs[1] * val
    z0 = xs[2] * val
    p1 = xs[3] * val
    p2 = xs[4] * val
    
    x0,y0,z0 = InitPRNG(x0,y0,p1,z0,p2,20)    
    return x0,y0,p1,z0,p2

def Enc(a,SortKey,ValueKey,scale,diffRound=1):
#     print(SortKey, SortKey.shape)
    w,h = a.shape
    k = SortKey
    #confusion
    c =  np.zeros((w,h), dtype=int)
    c = a.copy().flatten()
#     print(len(k))
    for i in range(len(k)):
        temp = c[i]
        c[i] = c[k[i]]
        c[k[i]] = temp
        
    b = np.zeros((w,h), dtype=int)
    b = c.copy().reshape((w,h))
    for iwhole in range(diffRound):
        #step2.1 diffuse row
        for iRow in range(0,w,1):
#             print(iRow, end="")
            if iRow == 0:
                b[iRow,:] = (b[-1,:] + b[iRow,:] + ValueKey[iRow,:]) % scale
            else:
                b[iRow,:] = (b[iRow-1,:] + b[iRow,:] + ValueKey[iRow,:]) % scale

        #step2.2 diffuse column
        for iCol in range(0,h,1):
            if iCol == 0:
                b[:, iCol] = (b[:, -1] + b[:, iCol] + ValueKey[:, iCol]) % scale
            else:
                b[:, iCol] = (b[:, iCol-1] + b[:, iCol] + ValueKey[:, iCol]) % scale


    return b

def Dec(a,SortKey,ValueKey,scale,diffRound=1):
    w,h = a.shape
    c =  np.zeros((w,h), dtype=int)
    c = a.copy()
    k = SortKey
    
    for iwhole in range(diffRound):
        for iCol in range(h-1,-1,-1):
            if iCol == 0:
                c[:, iCol] = (c[:, iCol] - c[:, -1] - ValueKey[:, iCol]) % scale
            else:
                c[:, iCol] = (c[:, iCol] - c[:, iCol-1] - ValueKey[:, iCol]) % scale
        for iRow in range(w-1,-1,-1):
            if iRow == 0:
                c[iRow,:] = (c[iRow,:] - c[-1,:] - ValueKey[iRow,:])% scale
            else:
                c[iRow,:] = (c[iRow,:] - c[iRow-1,:] - ValueKey[iRow,:])% scale 
    
    b =  np.zeros((w,h), dtype=int)
    b = c.copy().flatten()
    #confusion
    for i in range(len(k)-1, -1, -1):
        temp = b[i]
        b[i] = b[k[i]]
        b[k[i]] = temp
    return b.reshape((w,h))


def DoEnc(img,k=None, round=2):
    n = round # Encryption round
    w,h = img.shape #return row and column
    keys = []
    for i in range(n):
        x0,y0,p1,z0,p2 = getParas(img)
        keys.append((x0, y0, p1, z0, p2))
#         print("Encryption: ", (x0, y0, p1, z0, p2))
        sort,valuekey,x0,y0,z0 = getPRNG(w,h,1,x0,y0,p1,z0,p2)
        arr = np.array(sort)
        sortkey = arr[:,0]
        img = Enc(img,sortkey,valuekey,256,2)
    return img, keys


def DoDec(img,k,round = 2):
    n = round # Encryption round    
    w,h = img.shape #return row and column
    for i in range(n-1,-1,-1):
        x0,y0,p1,z0,p2 = k[i]
#         print("Decryption: ", (x0, y0, p1, z0, p2))
        sort,valuekey,x0,y0,z0 = getPRNG(w,h,1,x0,y0,p1,z0,p2)
        arr = np.array(sort)
        sortkey = arr[:,0]
        img = Dec(img,sortkey,valuekey,256,2)
    return img

# %%
def DoColorEnc(img,k=None, round=2):
    n = round # Encryption round
    #step1. initialization
    
    w,h,d = img.shape #return row and column
    img = img.reshape((w,h*d))
#     print(img.shape)
    keys = list()
    for i in range(n):
        x0,y0,p1,z0,p2 = getParas(np.ascontiguousarray(img))
        if k is not None:
            z0 += 1
        keys.append((x0,y0,p1,z0,p2))
        sort,valuekey,x0,y0,z0 = getPRNG(w,h*d,1,x0,y0,p1,z0,p2)
        arr = np.array(sort)
        sortkey = arr[:,0]
        img = Enc(img,sortkey,valuekey,256,2)
    
    img = img.reshape((w,h,d))
    return img, keys

def DoColorDec(img, k, round=2):
    n = round # Encryption round    
    w,h,d = img.shape #return row and column
    img = img.reshape((w,h*d))
    for i in range(n-1,-1,-1):
        x0,y0,p1,z0,p2 = k[i]
        sort,valuekey,x0,y0,z0 = getPRNG(w,h*d,1,x0,y0,p1,z0,p2)
        arr = np.array(sort)
        sortkey = arr[:,0]
        img = Dec(img,sortkey,valuekey,256,2)
    img = img.reshape((w,h,d))
    return img

def ObjectDetectionTest(file, crop=True, draw=False):
    og = cv2.imread(file)
    og = cv2.cvtColor(og, cv2.COLOR_BGR2RGB)
    
    if crop:
        start_det = time.perf_counter()
        img, (x, y) = detect_object(file,draw=draw)
        end_det = time.perf_counter()
        print("Detection Time:", (end_det - start_det))
        if img.size > 0:
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        else:
            print(img)
            print("No Object Detected!")
            return
    else:
        img = og

#     img = cv2.imread(file)
    print("Image Size:", og.shape)
    print("Detected Shape", img.shape)

    plt.figure(figsize=(20, 18))
    plt.subplot(1, 3, 1)
    plt.imshow(og, cmap="gray")
    plt.title("Original Image")
    
    if crop:
        plt.subplot(1, 3, 2)
        plt.imshow(img, cmap="gray")
        plt.title("Object Detected")
    
    start_enc = time.perf_counter()
    encrypted, keys = DoColorEnc(img, round=1)
    end_enc = time.perf_counter()
    print("Encryption Time:", (end_enc - start_enc))
    
    start_dec = time.perf_counter()
    decrypted = DoColorDec(img, keys, round=1)
    end_dec = time.perf_counter()
    print("Decryption Time:", (end_dec - start_dec))
    
    if crop:
        og[y:y+encrypted.shape[0], x: x+encrypted.shape[1]] = encrypted
    else:
        og = encrypted
    
    plt.subplot(1, 3, 3)
    plt.imshow(og)
    plt.title("Encrypted")
    plt.show()
    
    if crop:
         return (file, og.shape, (end_enc - start_enc), (end_dec - start_enc), (x, y, img.shape[0], img.shape[1]))
    
    return (file, og.shape, (end_enc - start_enc), (end_dec - start_enc))
    
# ObjectDetectionTest("./new/group.jpg")
# ObjectDetectionTest("./new/group.jpg", crop=False)

def ColorDetectionTest(draw=False, to_file=None):
    path = "./new/"
    arr = []
    for file in os.listdir(path):
        print(path+file)
        _, shape, enctime, dectime, coords = ObjectDetectionTest(path + file, draw=draw)
        _, shape, totalenctime, totaldectime = ObjectDetectionTest(path + file, crop=False)
        arr.append((file, shape, totalenctime, totaldectime, enctime, dectime, coords[0], coords[1], coords[2], coords[3]))
    arr = np.array(arr)
    arr = pd.DataFrame(arr, columns=["File Name", "Image Size", "Total Encryption Time", "Total Decryption Time", "Encryption Time", "Decryption Time", "X", "Y", "Width", "Height"])
    
    print(arr.head())
    if to_file:
        arr.to_csv(to_file, index=False)

# ColorDetectionTest(draw=True, to_file= "data.csv")

# %%
#information entropy global
def entropy(img):
    tmp = np.zeros(256)
    val = 0
    k = 0
    res = 0
    for i in range(len(img)):
        for j in range(len(img[i])):
            val = img[i][j]
            tmp[val] = float(tmp[val] + 1)
            k =  float(k + 1)
    for i in range(len(tmp)):
        tmp[i] = float(tmp[i] / k)
    for i in range(len(tmp)):
        if(tmp[i] == 0):
            res = res
        else:
            res = float(res - tmp[i] * (math.log(tmp[i]) / math.log(2.0)))
    return res

def infEntropy(plain,cipher):
    print("Information Entropy:")
    res0 = 0
    res1 = 0
    r0 = plain[:,:,0]
    res0 += entropy(r0)
    r1 = cipher[:,:,0]
    res1 += entropy(r1)
    
    r0 = plain[:,:,1]
    res0 += entropy(r0)
    r1 = cipher[:,:,1]
    res1 += entropy(r1)
    
    r0 = plain[:,:,2]
    res0 += entropy(r0)
    r1 = cipher[:,:,2]
    res1 += entropy(r1)
    
    res0 = res0/3
    res1 = res1/3
    
    print("Pic Entropy is:"+ str(res0)+ "\nThen,Encrypted Pic Entropy is:"+str(res1))
    return res0, res1
def globalEntropyTest(to_file = None):
    path = "./new/"
    pictures = os.listdir(path)
#     key = [0x7833A013F4DB0018F4FB4031E9F680BC614A,0x7833A013F4DB0018F4FB4031E9F680BC614B] 
    icount = 0
    entropies = []
    for picName in pictures:
        picPath = path + picName
        print(picName,"'s Global entropy:")
        lenna_img = np.array(Image.open(picPath))
        lenna_cipher, keys = DoColorEnc(lenna_img,round=1)
        lenna_img = np.array(Image.open(picPath))
        res1, res2 = infEntropy(lenna_img,lenna_cipher)
        entropies.append((picName, res1, res2))
    if to_file:
        entropies = np.array(entropies)
        entropies = pd.DataFrame(entropies, columns=["Image name", "Orginal", "Encrypted"])
        entropies.to_csv("entropies-"+to_file, index=False)

globalEntropyTest(to_file="data.csv")
# Out:
# 121.png 's Global entropy:
# Information Entropy:
# Pic Entropy is:7.38872478363015
# Then,Encrypted Pic Entropy is:7.999609928133322
# 181.png 's Global entropy:
# Information Entropy:
# Pic Entropy is:6.60072712137491
# Then,Encrypted Pic Entropy is:7.997218304941524
# 184.png 's Global entropy:
# Information Entropy:
# Pic Entropy is:6.919317714050525
# Then,Encrypted Pic Entropy is:7.997173128472222
# 204.png 's Global entropy:
# Information Entropy:
# Pic Entropy is:6.81226981474702
# Then,Encrypted Pic Entropy is:7.997457793594436
# 207.png 's Global entropy:
# Information Entropy:
# Pic Entropy is:7.340709946865346
# Then,Encrypted Pic Entropy is:7.997220531773703
# 209.png 's Global entropy:
# Information Entropy:
# Pic Entropy is:7.450934990149061
# Then,Encrypted Pic Entropy is:7.997262837097698
# 21.png 's Global entropy:
# Information Entropy:
# Pic Entropy is:6.795976555178675
# Then,Encrypted Pic Entropy is:7.999550523747819
# 222.png 's Global entropy:
# Information Entropy:
# Pic Entropy is:7.103590463886726
# Then,Encrypted Pic Entropy is:7.997194059317825
# 272.png 's Global entropy:
# Information Entropy:
# Pic Entropy is:7.268464626031029
# Then,Encrypted Pic Entropy is:7.996764099910778
# 312.png 's Global entropy:
# Information Entropy:
# Pic Entropy is:7.306226864157533
# Then,Encrypted Pic Entropy is:7.997086485774406
# 335.png 's Global entropy:
# Information Entropy:
# Pic Entropy is:7.42800003851809
# Then,Encrypted Pic Entropy is:7.997362710645156
# 362.png 's Global entropy:
# Information Entropy:
# Pic Entropy is:7.098167454655974
# Then,Encrypted Pic Entropy is:7.9969029766999205
# 373.png 's Global entropy:
# Information Entropy:
# Pic Entropy is:6.78755154728001
# Then,Encrypted Pic Entropy is:7.997413708933336
# 398.png 's Global entropy:
# Information Entropy:
# Pic Entropy is:7.427827392162214
# Then,Encrypted Pic Entropy is:7.996960910682525
# 406.png 's Global entropy:
# Information Entropy:
# Pic Entropy is:7.57882039868896
# Then,Encrypted Pic Entropy is:7.99733352195103
# 520.png 's Global entropy:
# Information Entropy:
# Pic Entropy is:7.461231216707644
# Then,Encrypted Pic Entropy is:7.999323588065555
# 526.png 's Global entropy:
# Information Entropy:
# Pic Entropy is:7.308289667321038
# Then,Encrypted Pic Entropy is:7.9993814241841115
# 58.png 's Global entropy:
# Information Entropy:
# Pic Entropy is:6.804993239168866
# Then,Encrypted Pic Entropy is:7.998346527589189
# 80.png 's Global entropy:
# Information Entropy:
# Pic Entropy is:6.945584728082633
# Then,Encrypted Pic Entropy is:7.999169058781984
# group.jpg 's Global entropy:
# Information Entropy:
# Pic Entropy is:7.2673087258741775
# Then,Encrypted Pic Entropy is:7.998923951056565

# %% [markdown]
# # Cropped Global Entropy

# %%
#information entropy global
def entropy(img):
    tmp = np.zeros(256)
    val = 0
    k = 0
    res = 0
    for i in range(len(img)):
        for j in range(len(img[i])):
            val = img[i][j]
            tmp[val] = float(tmp[val] + 1)
            k =  float(k + 1)
    for i in range(len(tmp)):
        tmp[i] = float(tmp[i] / k)
    for i in range(len(tmp)):
        if(tmp[i] == 0):
            res = res
        else:
            res = float(res - tmp[i] * (math.log(tmp[i]) / math.log(2.0)))
    return res

def infEntropy(plain,cipher):
    print("Information Entropy:")
    res0 = 0
    res1 = 0
    r0 = plain[:,:,0]
    res0 += entropy(r0)
    r1 = cipher[:,:,0]
    res1 += entropy(r1)
    
    r0 = plain[:,:,1]
    res0 += entropy(r0)
    r1 = cipher[:,:,1]
    res1 += entropy(r1)
    
    r0 = plain[:,:,2]
    res0 += entropy(r0)
    r1 = cipher[:,:,2]
    res1 += entropy(r1)
    
    res0 = res0/3
    res1 = res1/3
    
    print("Pic Entropy is:"+ str(res0)+ "\nThen,Encrypted Pic Entropy is:"+str(res1))
    return res0, res1
def globalEntropyTestCropped(to_file = None):
    path = "./new/"
    pictures = os.listdir(path)
#     key = [0x7833A013F4DB0018F4FB4031E9F680BC614A,0x7833A013F4DB0018F4FB4031E9F680BC614B] 
    icount = 0
    entropies = []
    for picName in pictures:
        picPath = path + picName
        print(picName,"'s Global entropy:")
        lenna_img, (x, y) = detect_object(picPath)
        lenna_cipher, keys = DoColorEnc(lenna_img,round=1)
        res1, res2 = infEntropy(lenna_img,lenna_cipher)
        entropies.append((picName, res1, res2))
    if to_file:
        entropies = np.array(entropies)
        entropies = pd.DataFrame(entropies, columns=["Image name", "Orginal", "Encrypted"])
        entropies.to_csv("entropies-cropped-"+to_file, index=False)

globalEntropyTestCropped(to_file="data.csv")
# Out:
# 121.png 's Global entropy:
# Information Entropy:
# Pic Entropy is:7.336408305556616
# Then,Encrypted Pic Entropy is:7.998327144187862
# 181.png 's Global entropy:
# Information Entropy:
# Pic Entropy is:7.080090873554791
# Then,Encrypted Pic Entropy is:7.979507741060627
# 184.png 's Global entropy:
# Information Entropy:
# Pic Entropy is:7.232001208108556
# Then,Encrypted Pic Entropy is:7.9964271618333775
# 204.png 's Global entropy:
# Information Entropy:
# Pic Entropy is:6.941072658001079
# Then,Encrypted Pic Entropy is:7.991576907268635
# 207.png 's Global entropy:
# Information Entropy:
# Pic Entropy is:7.093050527229906
# Then,Encrypted Pic Entropy is:7.994734381363223
# 209.png 's Global entropy:
# Information Entropy:
# Pic Entropy is:6.694321983859965
# Then,Encrypted Pic Entropy is:7.994274425510343
# 21.png 's Global entropy:
# Information Entropy:
# Pic Entropy is:7.244737710841335
# Then,Encrypted Pic Entropy is:7.997413823747453
# 222.png 's Global entropy:
# Information Entropy:
# Pic Entropy is:7.474250355395554
# Then,Encrypted Pic Entropy is:7.9879145240687945
# 272.png 's Global entropy:
# Information Entropy:
# Pic Entropy is:6.91188141869031
# Then,Encrypted Pic Entropy is:7.9832392339828315
# 312.png 's Global entropy:
# Information Entropy:
# Pic Entropy is:7.189669162637773
# Then,Encrypted Pic Entropy is:7.979325858751664
# 335.png 's Global entropy:
# Information Entropy:
# Pic Entropy is:6.9506313176989645
# Then,Encrypted Pic Entropy is:7.99216605689909
# 362.png 's Global entropy:
# Information Entropy:
# Pic Entropy is:7.153461280946726
# Then,Encrypted Pic Entropy is:7.960421431885629
# 373.png 's Global entropy:
# Information Entropy:
# Pic Entropy is:6.912312055212055
# Then,Encrypted Pic Entropy is:7.990635121559696
# 398.png 's Global entropy:
# Information Entropy:
# Pic Entropy is:7.286621092736881
# Then,Encrypted Pic Entropy is:7.971882643408594
# 406.png 's Global entropy:
# Information Entropy:
# Pic Entropy is:7.598629384775491
# Then,Encrypted Pic Entropy is:7.991849249722983
# 520.png 's Global entropy:
# Information Entropy:
# Pic Entropy is:7.328866159889478
# Then,Encrypted Pic Entropy is:7.987606520612367
# 526.png 's Global entropy:
# Information Entropy:
# Pic Entropy is:7.5365205672448
# Then,Encrypted Pic Entropy is:7.995717608116074
# 58.png 's Global entropy:
# Information Entropy:
# Pic Entropy is:6.798802027195165
# Then,Encrypted Pic Entropy is:7.981621871408513
# 80.png 's Global entropy:
# Information Entropy:
# Pic Entropy is:7.199025491913981
# Then,Encrypted Pic Entropy is:7.983904831813366
# group.jpg 's Global entropy:
# Information Entropy:
# Pic Entropy is:7.651382303341488
# Then,Encrypted Pic Entropy is:7.998615501428801
